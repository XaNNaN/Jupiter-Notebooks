# %%
import pandas as pd

# %%
df = pd.read_excel("EVM_2022.xls")
df.head(7)
# Out:
#     Группа     Фамилия        Имя    Отчество  РК1/10  РК1доп/3  РК2/15  \
# 0  РК6-71Б     Ахмедов  Аббос-Али  Раджабович    10.0         0     4.0
# 1  РК6-71Б    Бельская      Софья  Алексеевна    10.0         3    13.0
# 2  РК6-71Б      Блинов    Виталий  Витальевич    10.0         0     8.0
# 3  РК6-71Б     Борисов     Сергей  Дмитриевич     NaN         0    12.0
# 4  РК6-71Б      Гунько     Никита   Макарович    10.0         0     8.0
# 5  РК6-71Б     Ерофеев  Александр   Андреевич    10.0         1     8.0
# 6  РК6-71Б  Идиатуллин     Андрей   Андреевич     NaN         0     NaN
#
#    ЛР1/25  ЛР2/10  ЛР3/15  ...  Бонус стабильность  Штраф стабильность  \
# 0     6.0     5.0     8.0  ...                 NaN                 NaN
# 1    20.0     4.0    10.0  ...                 4.0                 NaN
# 2    12.0     7.0    10.0  ...                 4.0                 NaN
# 3     NaN     NaN     0.0  ...                 NaN                -3.0
# ...

# %%
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000

# %%
df_sorted = df.sort_values(by="Сумма", ascending=False)
df_sorted.insert(0, "Место по рейтингу", [ i+1 for i in range(108)])
# df_sorted["Место по рейтингу"] = [ i for i in range(108)]

# %%
df_sorted[["Место по рейтингу", "Группа", "Фамилия", "Имя", "Сумма", "Оценка"]]
# Out:
#      Место по рейтингу   Группа       Фамилия         Имя  Сумма  Оценка
# 99                   1  РК6-76Б      Самойлов     Арсений    120     5.0
# 10                   2  РК6-71Б        Маслий   Владислав    110     5.0
# 41                   3  РК6-73Б       Василян       Артур    106     5.0
# 104                  4  РК6-76Б       Сутягин     Алексей    105     5.0
# 27                   5  РК6-72Б     Максимова   Елизавета    104     5.0
# 32                   6  РК6-72Б    Тугаринова   Анастасия    102     5.0
# 23                   7  РК6-72Б    Зайковская   Анастасия    101     5.0
# 45                   8  РК6-73Б  Калистратова  Александра     99     5.0
# 50                   9  РК6-73Б        Минина       Дарья     98     5.0
# 13                  10  РК6-71Б        Плыкин      Сергей     97     5.0
# 8                   11  РК6-71Б      Мамченко       Ольга     97     5.0
# 25                  12  РК6-72Б         Конов       Антон     96     5.0
# ...

# %%
# !pip install xlwt

# %%
import xlwt
df_sorted[["Место по рейтингу", "Группа", "Фамилия", "Имя", "Сумма", "Оценка"]].to_excel("EVM_2022_sorted.xls")
# Out:
# c:\temp\ipykernel_15512\3878151593.py:2: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   df_sorted[["Место по рейтингу", "Группа", "Фамилия", "Имя", "Сумма", "Оценка"]].to_excel("EVM_2022_sorted.xls")
